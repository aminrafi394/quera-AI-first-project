# %% [markdown]
# <a href="https://colab.research.google.com/github/aminrafi394/quera-AI-first-project/blob/Amirreza/ProjectOne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First we imported the  neccery libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Now we read the data frame. The file is in the google driver so we import drive library from google colab to access the data frame.

# %%
from google.colab import drive

drive.mount("/content/drive")

data_frame_path = "/content/drive/MyDrive/Divar.csv"

data_frame = pd.read_csv(data_frame_path)

data_frame.head(10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /tmp/ipykernel_8326/797180065.py:7: DtypeWarning: Columns (11,27,29,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = pd.read_csv(data_frame_path)
#    Unnamed: 0         cat2_slug       cat3_slug      city_slug  \
# 0           0    temporary-rent           villa          karaj
# 1           1  residential-sell  apartment-sell         tehran
# 2           2  residential-rent  apartment-rent         tehran
# 3           3   commercial-rent     office-rent         tehran
# 4           4  residential-sell  apartment-sell        mashhad
# 5           5  residential-rent  apartment-rent          ahvaz
# 6           6   commercial-rent     office-rent     kermanshah
# 7           7  residential-sell  apartment-sell         tehran
# 8           8  residential-sell  apartment-sell  mahdasht-city
# 9           9  residential-sell  apartment-sell        mashhad
#
#   neighborhood_slug     created_at_month    user_type  \
# 0         mehrshahr  2024-08-01 00:00:00  مشاور املاک
# 1           gholhak  2024-05-01 00:00:00  مشاور املاک
# 2             tohid  2024-10-01 00:00:00          NaN
# 3          elahiyeh  2024-06-01 00:00:00          NaN
# 4          emamreza  2024-05-01 00:00:00  مشاور املاک
# 5          mellirah  2024-09-01 00:00:00          NaN
# 6               NaN  2024-11-01 00:00:00          NaN
# 7          dardasht  2024-09-01 00:00:00  مشاور املاک
# 8               NaN  2024-06-01 00:00:00  مشاور املاک
# 9    faramarzabbasi  2024-10-01 00:00:00          NaN
#
#                                          description  \
# 0  ۵۰۰متر\n۲۰۰متر بنا دوبلکس\n۳خواب\nاستخر آبگرم ...
# 1  دسترسی عالی به مترو و شریعتی \nمشاعات تمیز \nب...
# 2                                    تخلیه پایان ماه
# 3  فرشته تاپ لوکیشن\n۹۰ متر موقعیت اداری\nیک اتاق...
# 4  هلدینگ ساختمانی اکبری\n\nهمراه شما هستیم برای ...
# 5  اپارتمان ۱۰۰متری واحد جلو دارای دو اتاق خواب ک...
# 6  ♦مشاورین املاک سیب♦\n✅️کد:G۱۰۵\n♦با سالها سابق...
# 7  ♡♡♡♡♡♡بنام خدا♡♡♡♡♡♡\n♡♡♡عرض ادب واحترام♡♡♡\n♡...
# 8  با سلام\n\nاملاک بزرگ اتحاد با ۲شعبه فعال با ف...
# 9  اول رسالت فرد  نزدیک به حاشیه فرامرز .. ساکنین...
#
#                                               title rent_mode  ...  \
# 0  باغ ویلا اجاره روزانه استخر داخل لشکرآباد سهیلیه       NaN  ...
# 1                           ۶۰ متر قلهک فول امکانات       NaN  ...
# 2                          آپارتمان ۳ خوابه ۱۳۲ متر     مقطوع  ...
# 3           فرشته ۹۰ متر دفتر کار مدرن موقعیت اداری     مقطوع  ...
# 4                  ۱۱۵ متری/شمالی رو به آفتاب/اکبری       NaN  ...
# 5                 اپارتمان ۱۰۰متری ملی راه واحد جلو     مقطوع  ...
# 6                      واحداداری ۸۰متری ۲۲بهمن(برق)     مقطوع  ...
# 7          اپارتمان ۱۰۰متری طبقه۳و۴ فول دردشت شمالی       NaN  ...
# 8      ۷۸متری دوبحرنورگیر بازسازی شده شیک سندتک برگ       NaN  ...
# 9                   متراژ ۸۰ متر فرامرز نزدیک حاشیه       NaN  ...
#
#    property_type regular_person_capacity extra_person_capacity  \
# 0            NaN                     4.0                     6
# 1            NaN                     NaN                   NaN
# 2            NaN                     NaN                   NaN
# 3            NaN                     NaN                   NaN
# 4            NaN                     NaN                   NaN
# 5            NaN                     NaN                   NaN
# 6            NaN                     NaN                   NaN
# 7            NaN                     NaN                   NaN
# 8            NaN                     NaN                   NaN
# 9            NaN                     NaN                   NaN
#
#   cost_per_extra_person  rent_price_on_regular_days  \
# 0              350000.0                   1500000.0
# 1                   NaN                         NaN
# 2                   NaN                         NaN
# 3                   NaN                         NaN
# 4                   NaN                         NaN
# 5                   NaN                         NaN
# 6                   NaN                         NaN
# 7                   NaN                         NaN
# 8                   NaN                         NaN
# 9                   NaN                         NaN
#
#   rent_price_on_special_days  rent_price_at_weekends location_latitude  \
# 0               3.500000e+09               3500000.0         35.811684
# 1                        NaN                     NaN               NaN
# 2                        NaN                     NaN         35.703865
# 3                        NaN                     NaN               NaN
# 4                        NaN                     NaN               NaN
# 5                        NaN                     NaN               NaN
# 6                        NaN                     NaN               NaN
# 7                        NaN                     NaN         35.729832
# 8                        NaN                     NaN         35.712364
# 9                        NaN                     NaN               NaN
#
#   location_longitude  location_radius
# 0          50.936600            500.0
# 1                NaN            500.0
# 2          51.373459              NaN
# 3                NaN              NaN
# 4                NaN              NaN
# 5                NaN              NaN
# 6                NaN              NaN
# 7          51.505466            500.0
# 8          50.794781            500.0
# 9                NaN              NaN
#
# [10 rows x 61 columns]

# %% [markdown]
# Lets see how much of the columns include Nan values.

# %%
data_frame.isna().sum()
# Out:
# Unnamed: 0                         0
# cat2_slug                          0
# cat3_slug                          1
# city_slug                          2
# neighborhood_slug             562861
#                                ...
# rent_price_on_special_days    989537
# rent_price_at_weekends        986449
# location_latitude             344392
# location_longitude            344392
# location_radius               660301
# Length: 61, dtype: int64

# %% [markdown]
# For the task number 6 in the statical section we need rent_values, rent_mode,
# created_at_month

# %%
target_df = data_frame[["rent_value", "created_at_month"]]
target_df.head(10)
# Out:
#    rent_value     created_at_month
# 0         NaN  2024-08-01 00:00:00
# 1         NaN  2024-05-01 00:00:00
# 2  26000000.0  2024-10-01 00:00:00
# 3  95000000.0  2024-06-01 00:00:00
# 4         NaN  2024-05-01 00:00:00
# 5   6000000.0  2024-09-01 00:00:00
# 6  16000000.0  2024-11-01 00:00:00
# 7         NaN  2024-09-01 00:00:00
# 8         NaN  2024-06-01 00:00:00
# 9         NaN  2024-10-01 00:00:00

# %% [markdown]
# Now we change the created time to the solar calender date but we just need months.

# %%
from sklearn.preprocessing import FunctionTransformer

def trun_grogorian_solar_month(data_frame : pd.DataFrame):
  # Here we change the data type to the pd.DateTime.
  data_frame["created_at_month"] = pd.to_datetime(data_frame["created_at_month"])

  # Here we just take month and remove the created_at_month
  data_frame["month"] = data_frame["created_at_month"].dt.month
  data_frame = data_frame.drop(columns=["created_at_month"])

  # Here we turn the month of the Gregorian date into solar calender.
  map_gregorian_solar = {
      1 : "دی", 2 : "بهمن", 3 : "اسفند", 4 : "فروردین", 5 : "اردیبهشت", 6 : "خرداد",
      7 : "تیر", 8 : "مرداد", 9 : "شهریور", 10 : "مهر", 11 : "آبان", 12 : "آذر"
  }
  data_frame["month"] = data_frame["month"].map(map_gregorian_solar)

  return data_frame

# Enableing the function to be used in the PipeLine.
trun_grogorian_solar_month = FunctionTransformer(trun_grogorian_solar_month)
target_df = trun_grogorian_solar_month.transform(target_df)


target_df[target_df.month == "فروردین"].isna().sum()
# Out:
# /tmp/ipykernel_8326/3540549201.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame["created_at_month"] = pd.to_datetime(data_frame["created_at_month"])
# /tmp/ipykernel_8326/3540549201.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame["month"] = data_frame["created_at_month"].dt.month
# rent_value    6276
# month            0
# dtype: int64

# %% [markdown]
# In this Part we fill Nan values of the ren_value.

# %%
def fill_nan_rent_value(data_frame : pd.DataFrame):
  # Fill the Nan values based on the median of elements grouped by month.
  rent_value_month_median = data_frame.groupby(["month"]).median()
  data_frame["rent_value"] = data_frame["rent_value"].fillna(
      data_frame.groupby("month")["rent_value"].transform("median")
  )
  return data_frame

# Enableing the function to be used in the PipeLine.
fill_nan_rent_value = FunctionTransformer(fill_nan_rent_value)
target_df = fill_nan_rent_value.transform(target_df)
target_df.head(10)
# Out:
#    rent_value     month
# 0   5000000.0     مرداد
# 1   5000000.0  اردیبهشت
# 2  26000000.0       مهر
# 3  95000000.0     خرداد
# 4   5000000.0  اردیبهشت
# 5   6000000.0    شهریور
# 6  16000000.0      آبان
# 7   5000000.0    شهریور
# 8   4500000.0     خرداد
# 9   5000000.0       مهر

# %% [markdown]
# Plotting the histogram.(We need arabic reshape for the plot)

# %%
# !pip install arabic-reshaper python-bidi
# Out:
# Requirement already satisfied: arabic-reshaper in /usr/local/lib/python3.13/dist-packages (3.0.1)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.13/dist-packages (0.6.11)

# %%
import arabic_reshaper
from bidi.algorithm import get_display
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


def fix_fa(text: str) -> str:
    return get_display(arabic_reshaper.reshape(str(text)))

target_grouped = target_df.groupby("month")["rent_value"].mean()

month_order = [
    "فروردین",
    "اردیبهشت",
    "خرداد",
    "تیر",
    "مرداد",
    "شهریور",
    "مهر",
    "آبان",
    "آذر",
    "دی",
    "بهمن",
    "اسفند",
]
valid_months = [m for m in month_order if m in target_grouped.index]
target_grouped = target_grouped.reindex(valid_months)


x_labels = [fix_fa(m) for m in target_grouped.index]
y_values = target_grouped.values

figure, axes = plt.subplots(figsize=(12, 6))
sns.barplot(x=x_labels, y=y_values, color="turquoise", axes=axes, width=0.5)

plt.xticks(axes=axes, rotation=45)
axes.set_title("mean rent value base on the month", fontsize=14)
axes.set_xlabel("month", fontsize=12)
axes.set_ylabel("mean rent value", fontsize=12)

axes.spines["top"].set_visible(False)
axes.spines["left"].set_visible(False)
axes.spines["right"].set_visible(False)
axes.grid()
axes.legend()

plt.tight_layout()
# Out:
# /tmp/ipykernel_8326/927349542.py:46: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes.legend()

# %% [markdown]
# In this part we start the section 6 of the statical part.
# So we make a copy of the main data frame in an attemp to work with it in section 7

# %%
data_frame_7 = data_frame.copy()
data_frame_7 = data_frame_7[["price_value", 'created_at_month', "city_slug"]]

# %% [markdown]
# In this part we try convert the types of the (created_at_month) column into pd.DateTime.

# %%
# !pip install jdatetime
# Out:
# Requirement already satisfied: jdatetime in /usr/local/lib/python3.13/dist-packages (6.1.0)
# Requirement already satisfied: jalali-core>=1.0 in /usr/local/lib/python3.13/dist-packages (from jdatetime) (1.0.0)

# %%
from sklearn.preprocessing import FunctionTransformer
import jdatetime

def trun_grogorian_solar_year(data_frame : pd.DataFrame):
  # Convertnig to the DateTime.
  data_frame["created_at_month"] = pd.to_datetime(data_frame["created_at_month"])

  # Turning into the persian calender.
  data_frame["Year"] = data_frame["created_at_month"].apply(lambda d: jdatetime.date.fromgregorian(date=d.date()).year)
  data_frame = data_frame.drop(columns=["created_at_month"])

  return data_frame

trun_grogorian_solar_year = FunctionTransformer(trun_grogorian_solar_year)
data_frame_7 = trun_grogorian_solar_year.transform(data_frame_7)

data_frame_7.groupby("Year")

# %% [markdown]
# In this part we full fill the nan values with median of the price_value grouped by the year.

# %%
# The number of the city slug which has the Nan values is too low in the comparasion with the one million line.
# So we can drop them.
labels = (data_frame_7["city_slug"].isna() == True)
data_frame_7 = data_frame_7[~labels]


def fill_price_value(data_frame : pd.DataFrame):
  # Removing the rows with Nan city_slug.
  data_frame = data_frame.dropna(subset=["city_slug"])
  data_frame['price_value'] = data_frame['price_value'].fillna(
      data_frame.groupby(['city_slug', 'Year'])['price_value'].transform('median')
  )
  return data_frame

fill_price_value = FunctionTransformer(fill_price_value)
data_frame_7 = fill_price_value.transform(data_frame_7)


def remove_outliers_iqr_price_value(df, column='price_value'):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Some cities may need more money to buy a house and may be removed .
# what will you do :
def clean_and_aggregate(df):
    df_clean = df.dropna(subset=["city_slug", "price_value"]).groupby(
        ["city_slug", "Year"], group_keys=False
    ).apply(remove_outliers_iqr_price_value)

    result = df_clean.groupby("Year")["price_value"].median()
    return result

clean_and_aggregate = FunctionTransformer(clean_and_aggregate)
data_frame_7 = clean_and_aggregate.transform(data_frame_7)
# Out:
# /tmp/ipykernel_8326/56967114.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ).apply(remove_outliers_iqr_price_value)

# %% [markdown]
# Now we just plot the bar with sns.(without considering the inflation)

# %%
data_frame_7 = pd.DataFrame(data_frame_7)

data_frame_7 = data_frame_7.groupby("Year").mean()
data_frame_7 = data_frame_7.iloc[1:]

figure , axes = plt.subplots(figsize=(20, 7))

sns.barplot(
    x=data_frame_7.index,
    y=data_frame_7["price_value"],
    color="mediumaquamarine",
    ax = axes,
    alpha=0.7
)
axes.spines["top"].set_visible(False)
axes.spines["left"].set_visible(False)
axes.spines["right"].set_visible(False)
axes.set_xlabel("Year")
axes.set_ylabel("Price_value")
axes.set_title("mean price in the year without considering CPI")
axes.grid()
axes.legend()
# Out:
# /tmp/ipykernel_8326/2924026589.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes.legend()

# %% [markdown]
# In this part we consider the inflation of each year.
# Also we search the cpi and the other coefficients from the internet and effect it in our data.

# %%
cpi_rates = {
    1400 : 719,
    1401 : 1031,
    1402 : 1480,
    1403 : 2140
}

data_frame_7_cpi = data_frame_7.copy()
cpi_frame = data_frame_7_cpi.index.map(cpi_rates)
data_frame_7_cpi["price_value"] = (data_frame_7_cpi["price_value"] / cpi_frame) * cpi_rates[1400]
data_frame_7_cpi
# Out:
#        price_value
# Year
# 1400  1.200000e+09
# 1401  1.774835e+09
# 1402  1.457432e+09
# 1403  9.273084e+08

# %% [markdown]
# Now we plot the real price_value

# %%
figure , axes = plt.subplots(figsize=(20, 7))


sns.barplot(
    x=data_frame_7_cpi.index,
    y=data_frame_7_cpi["price_value"],
    color="olivedrab",
    ax = axes,
    alpha=0.7
)
axes.spines["top"].set_visible(False)
axes.spines["left"].set_visible(False)
axes.spines["right"].set_visible(False)
axes.set_xlabel("Year")
axes.set_ylabel("Price_value")
axes.set_title("mean price in the year considering CPI")
axes.grid()
axes.legend()
# Out:
# /tmp/ipykernel_8326/299377554.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes.legend()

# %% [markdown]
# We start the section 3 of the second part of the static.

# %%
data_frame_3 = data_frame.copy()

# %%
data_frame_3 = data_frame_3[["has_business_deed", "price_value", "city_slug", "created_at_month"]]
data_frame_3 = data_frame_3.dropna(subset=["city_slug"])

# Some operations to fill the Nan values of the price_value and removing the outliers.
data_frame_3 = trun_grogorian_solar_year.transform(data_frame_3)
data_frame_3 = fill_price_value.transform(data_frame_3)
data_frame_3 = data_frame_3.dropna(subset=["city_slug", "price_value"]).groupby(
        ["city_slug", "Year"], group_keys=False
    ).apply(remove_outliers_iqr_price_value)
# Out:
# /tmp/ipykernel_8326/2993788030.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ).apply(remove_outliers_iqr_price_value)

# %%
data_frame_3 = pd.DataFrame(data_frame_3)

labels = data_frame_3.has_business_deed.isna()
target = data_frame_3[~labels]
has_business_True = target[target["has_business_deed"] == True]["price_value"]
has_business_False = target[target["has_business_deed"] == False]["price_value"]
has_business_True
# Out:
# 646340    8.000000e+08
# 957333    8.000000e+08
# 126179    1.600000e+09
# 181568    2.230000e+09
# 291369    1.600000e+09
#               ...
# 189717    3.700000e+09
# 612543    3.550000e+09
# 660934    3.700000e+09
# 778574    1.700000e+09
# 224186    1.230000e+09
# Name: price_value, Length: 6841, dtype: float64

# %% [markdown]
# Now we want to determine whether the distributions of the two samples are normal or not.

# %%
from scipy.stats import shapiro
shapiro_stat_True, shapiro_pvalue_True = shapiro(has_business_True)
shapiro_stat_False, shapiro_pvalue_False = shapiro(has_business_False)

print("The shapiro p_values : ")
print(f"Shapiro p_value True : {shapiro_pvalue_True}")
print(f"Shapiro p_value False : {shapiro_pvalue_False}")
# Out:
# The shapiro p_values :
# Shapiro p_value True : 4.300877400057761e-67
# Shapiro p_value False : 1.5091101424060784e-74
# /usr/local/lib/python3.13/dist-packages/scipy/stats/_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6841.
#   res = hypotest_fun_out(*samples, **kwds)
# /usr/local/lib/python3.13/dist-packages/scipy/stats/_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 7197.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# The p_values show that the distributions are not normal so we use man_whitnee test.
# The H0 : if a value of the property which has has_business_deed is greater equal than the property which does not have has_business_deed.

# %%
from scipy.stats import mannwhitneyu

u_state, p_value = mannwhitneyu(has_business_True, has_business_False, alternative="less")
print(f"p_value : {p_value}")


print(target.columns)
# Out:
# p_value : 0.4543775687532013
# Index(['has_business_deed', 'price_value', 'city_slug', 'Year'], dtype='object')

# %% [markdown]
# The p_value is too much greater than the treshold so it show thta th H0 can not be rejcted.
# The alternative assumption is false.

# %%
# For option you can plot some barplot. ask this one !!!!.
have_deed = target[target["has_business_deed"] == True]
not_have_deed = target[target["has_business_deed"] == False]

have_deed = pd.DataFrame(have_deed.groupby("Year")["price_value"].mean())
not_have_deed = pd.DataFrame(not_have_deed.groupby("Year")["price_value"].mean())

have_deed
# Out:
#        price_value
# Year
# 1402  5.456529e+09
# 1403  2.678811e+09

# %%
figure , axes = plt.subplots(1, 2, figsize=(20, 7))

sns.barplot(
    x=not_have_deed.index,
    y=not_have_deed["price_value"],
    color="mediumaquamarine",
    ax = axes[0],
    alpha=0.3
)

sns.barplot(
    x=have_deed.index,
    y=have_deed["price_value"],
    color="royalblue",
    ax = axes[1],
    alpha=0.3
)

axes[0].spines["top"].set_visible(False)
axes[0].spines["left"].set_visible(False)
axes[0].spines["right"].set_visible(False)
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Price_value")
axes[0].set_title("mean price in the year considering CPI for not have_dee")
axes[0].grid()
axes[0].legend()


axes[1].spines["top"].set_visible(False)
axes[1].spines["left"].set_visible(False)
axes[1].spines["right"].set_visible(False)
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Price_value")
axes[1].set_title("mean price in the year considering CPI for have_deed")
axes[1].grid()
axes[1].legend()

# This limitation make them comparable in the plots.
max_y = 8.5e10

axes[0].set_ylim(0, max_y)
axes[1].set_ylim(0, max_y)
# Out:
# /tmp/ipykernel_8326/2222340217.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend()
# /tmp/ipykernel_8326/2222340217.py:36: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend()
# (0.0, 85000000000.0)
